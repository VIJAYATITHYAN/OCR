# %% [markdown]
# <a href="https://colab.research.google.com/github/VIJAYATITHYAN/OCR/blob/main/OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]

# %%
# !pip install keras-ocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get install tesseract-ocr
# !pip install pytesseract
# !apt-get install tesseract-ocr libtesseract-dev libleptonica-dev pkg-config
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu4).
# libleptonica-dev is already the newest version (1.79.0-1).
# libtesseract-dev is already the newest version (4.1.1-2build2).
# tesseract-ocr is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
import keras_ocr
import matplotlib.pyplot as plt
#import Pytesseract
# %matplotlib inline

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(images) for images in['/content/bill.png','/content/city board.jpg','/content/snooze.jpg']
]

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %%
plt.figure(figsize = (10,10))
plt.imshow(images[2])

# %%
predictions = pipeline.recognize(images)
# Out:
# ...
# 4/4 [==============================] - 18s 4s/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, predictions):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
